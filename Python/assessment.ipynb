# %%
a, b = map(int, input("10 20").split())

# %%
generate fibonacci addend series
trapping rain water
warehouse inventory low stock item

# %%
arr = list( map( int, input().split()))
for i in range(len(arr)):
    if i>a:
        a=i

print(a)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
arr = list( map( int, input().split()))
a=arr[0]
for i in arr:
    if i<a:
        a=i

print(a)

# %%
arr = list(map(int, input().ssplit()))
a = int(input())
count = 0
for i in arr:
    if i > a:
        count += 1

print(count)

# %%
#sum of even numbers
arr = list(map(int, input().split()))
a=0
for i in arr:
    if i %2==0:
        a+=i
print(a)
