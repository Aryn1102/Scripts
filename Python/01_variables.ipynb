# %%
"""VARIABLE

a variable is a name bound to an object which makes it reusable, improves redability. Python variables dont explicitly declare a datatype but use reference object"""
# Out:
# 'VARIABLE\n\na variable is a name bound to an object which makes it reusable, improves redability. Python variables dont explicitly declare a datatype but use reference object'

# %%
age = 22
name = "Raj Aryan"
college = "JSS"
cgpa = 6.22
is_student = True
weight = 52.90
skills = ["python", "SQL", "Git"]
Address = {"house no.": "LG-03", "Tower": "A", "Apartment": "Green Avenue", "Sector": "73"}

# %%
print(age)
print(type(age))
print(name)
print(type(name))
print(cgpa)
print(type(cgpa))
print(is_student)
print(type(is_student))
print(weight)
print(type(weight))
print(skills)
print(type(skills))
print(Address)
print(type(Address))
# Out:
# 22
# <class 'int'>
# Raj Aryan
# <class 'str'>
# 6.22
# <class 'float'>
# True
# <class 'bool'>
# 52.9
# <class 'float'>
# ['python', 'SQL', 'Git']
# <class 'list'>
# {'house no.': 'LG-03', 'Tower': 'A', 'Apartment': 'Green Avenue', 'Sector': '73'}
# <class 'dict'>

# %%
"""1st (start with no.)
bool (keyword)
my variable (space in variable name)
raj-aryan (contains hyphen)
$dollar (contains special character)
email@domain (contains special character)
if (keyword)
num.value (contains special character)
true (keyword)
for (keyword)
percent% (contains special character)
"""

# %%
a = 10
b = a
a = 20
print(a)
print(b)
"""value of a is initially 10 but later changesd to 20 and b is assigned the value of a before that so b remains 10"""
# Out:
# 20
# 10

# %%
"""
What is variable in python?
A variable is a name given to an object in memory.

What is dynamic typing in python?
Dynamic typing is when you dont have to initiallize a variable with a datatype. python automatically assign the datatype based on stored value in variable.

Difference between int and float in python?
int is a whole number datatype and float is a decimal number datatype.

What does type() rerturn?
type() return the datatype of the variable.

What is None?
None is a special type of data type in python which represents the absence of value.

Why should variable names be descriptive?
Variable names should be dscriptive so that it is easy to understand the purpose of the variable in the code and improves readability of the code.
"""
# Out:
# '\nWhat is variable in python?\nA variable is a name given to an object in memory.\n\nWhat is dynamic typing in python?\nDynamic typing is when you dont have to initiallize a variable with a datatype. python automatically assign the datatype based on stored value in variable.\n\nDifference between int and float in python?\nint is a whole number datatype and float is a decimal number datatype.\n\nWhat does type() rerturn?\ntype() return the datatype of the variable.\n\nWhat is None?\nNone is a special type of data type in python which represents the absence of value.\n\nWhy should variable names be descriptive?\nVariable names should be dscriptive so that it is easy to understand the purpose of the variable in the code and improves readability of the code.\n'
