# %%
a = 15
b = 4

# %%
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %%
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# True
# False
# False
# True
# True
# False

# %%
print(a>10 and b<5)
print(a>10 or b<5)
print(not(a>10 and b<5))
# Out:
# True
# True
# False

# %%
x=10
x+=5
x-=5
x*=5
x/=5

# %%
a = 25
b = 6
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 31
# 19
# 150
# 4.166666666666667
# 4
# 1
# 244140625

# %%
print(10 > 5)
print(10 == 5)
print(5 != 5)
print(10 >= 10)
print(7 < 3)
# Out:
# True
# False
# False
# True
# False

# %%
x = 10

x += 5
x *= 2
x -= 4
x //= 2

print(x)
# Out:
# 13

# %%
percentage = 85
print((percentage>=90 and percentage<=100) or (percentage>=80 and percentage<90) or (percentage>=70 and percentage<80) or (percentage>=60 and percentage<70) or (percentage<60))
# Out:
# True

# %%
mean = 75
print((mean>=90 and mean<=100) or (mean>=80 and mean<90) or (mean>=70 and mean<80) or (mean>=60 and mean<70) or (mean<60))
# Out:
# True

# %%
mean = 75
print(not((mean>=90 and mean<=100) or (mean>=80 and mean<90) or (mean>=70 and mean<80) or (mean>=60 and mean<70) or (mean<60)))
# Out:
# False

# %%
"""
Difference between / and //.
/ performs normal division and returns the quotient, while // performs floor division by rounding the result down to the nearest whole value.

Difference between = and ==.
= assign value of rhs to lhs and == checks whether rhs and lhs are equal or not.

Difference between and and or.
and return true only when both the conditions are true whereas or returns true when only one is true.

What does % return?
it returns the remainder of the division

What is operator precedence?
the priority order of the execution of operators in a equation.Parentheses () have the highest precedence and can be used to override the default order.

Why is == used instead of = in conditions?
to compare the lhs and rhs because = is used to assign the rhs to lhs
"""
# Out:
# '\nDifference between / and //.\n/ return float value whereas // return integer value.\n\nDifference between = and ==.\n= assign value of rhs to lhs and == checks whether rhs and lhs are equal or not.\n\nDifference between and and or.\nand return true only when both the conditions are true whereas or returns true when only one is true.\n\nWhat does % return?\nit returns the remainder of the division\n\nWhat is operator precedence?\nthe priority order of the execution of operators in a equation\n\nWhy is == used instead of = in conditions?\nto compare the lhs and rhs because - is used to assign the rhs to lhs\n'

# %%
2 + 3 * 4 ** 2
#2+3*16
#2+48
#50
print(2 + 3 * 4 ** 2)
# Out:
# 50
