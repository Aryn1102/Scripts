# %%
"""
Interview Questions
Answer these without looking back.

Q1.
What is hashing in the context of DSA?
Hashing maps a key to a location using a hash function, allowing dictionary/set lookup in average O(1) time.

Q2. ⭐
Why can a Python dictionary/set perform lookup in average O(1) time?
uses hashing to locate the relevant bucket/location without searching all elements

Q3.
When would you use a set instead of a dictionary?
when you need to know whether the element has previously occured or not 

Q4.
What is a frequency map?
frequency map is counting the no of occurences of the element

Q5.
What is the time and space complexity of:
seen = set()
for x in numbers:
    if x in seen:
        return True
    seen.add(x)
Explain why.
o(n) because  the loop iterates through the entire numbers list while seen is a set and insertion in set takes o(1) time

Q6. ⭐
Why does the brute-force Two Sum solution take O(n²)?
because there are tw loops one for elements and the  other for its complement iteration

Q7. ⭐⭐⭐
How does a hash map reduce Two Sum from O(n²) to average O(n)?
We iterate through the array once and use a hash map to check whether the complement has already been seen.
Hash-map lookup is average O(1), giving O(n) overall time.

Q8.
What does enumerate(numbers) give you?
the index and value at that index

Q9.
What is the difference between:
seen = set()
and:
seen = {}
for DSA purposes?
the first one is a set so it stores only unique values while the second one is dict which stores the key and its value
set is usefule for checking iccurence while dict can be used for frequency of elements, data associaated with the element

Q10. ⭐⭐⭐
You see this problem:
Given an array, determine whether any two numbers have the same value.
Before writing code, what data structure/pattern should immediately come to mind, and why?
hashing and hashmap
to lookup the previously occured items in list
def duplicate(nums):
    seen=set()
    for num in nums:
        if nums in seen:
            return True
        seen.add(num)
    return False
"""
# Out:
# '\nInterview Questions\nAnswer these without looking back.\n\nQ1.\nWhat is hashing in the context of DSA?\nHashing maps a key to a location using a hash function, allowing dictionary/set lookup in average O(1) time.\n\nQ2. ⭐\nWhy can a Python dictionary/set perform lookup in average O(1) time?\nuses hashing to locate the relevant bucket/location without searching all elements\n\nQ3.\nWhen would you use a set instead of a dictionary?\nwhen you need to know whether the element has previously occured or not \n\nQ4.\nWhat is a frequency map?\nfrequency map is counting the no of occurences of the element\n\nQ5.\nWhat is the time and space complexity of:\nseen = set()\nfor x in numbers:\n    if x in seen:\n        return True\n    seen.add(x)\nExplain why.\no(n) because  the loop iterates through the entire numbers list while seen is a set and insertion in set takes o(1) time\n\nQ6. ⭐\nWhy does the brute-force Two Sum solution take O(n²)?\nbecause there are tw loops one for elements and th
# ...

# %%
def contains_duplicate(numbers):
    seen=set()
    for num in numbers:
        if num in seen:
            return True
        seen.add(num)
    return False

# %%
def frequency_count(numbers):
    seen = {}
    for num in numbers:
        if num in seen:
            seen[num] +=1
        else:
            seen[num] = 1
    return seen

# %%
def first_duplicate(numbers):
    seen = set()
    for num in numbers:
        if num in seen:
            return num
        seen.add(num)
    return None

# %%
def two_sum(numbers, target):
    seen = {}
    for i, num in enumerate(numbers):
        com = target-num
        if com in seen:
            return i, seen[com]
        seen[num] = i
""" 
Why is this O(n) rather than O(n²)?
because there is one loop instead of two loops
"""
# Out:
# ' \nWhy is this O(n) rather than O(n²)?\nbecause there is one loop instead of two loops\n'

# %%
""" 
1. LC 217 — Contains Duplicate
seen = set()
        for num in nums:
            if num in seen:
                return True
            seen.add(num)
        return False
"""
# Out:
# ' \n1. LC 217 — Contains Duplicate\nseen = set()\n        for num in nums:\n            if num in seen:\n                return True\n            seen.add(num)\n        return False\n'

# %%
def contains_duplicate(numbers):
    seen = set()
    for num  in numbers:
        if num in seen:
            return True
        seen.add(num)
    return False

# %%
def frequency_count(numbers):
    freq={}
    for num in numbers:
        if num in freq:
            freq[num] += 1
        else:
            freq[num] = 1
    return freq

# %%
""" 
Explain this in plain English:
seen = {}
for i, num in enumerate(numbers):
    complement = target - num
    if complement in seen:
        return [seen[complement], i]
    seen[num] = i
Don't just say "it uses hashing."
Explain what is stored, what is searched, and when the answer is returned.

the loop is run using enumerate which gives the index and num,
the  num is subtracted from the target to obtain a value
this value is checked in seen to see whether it has appeared befor in the set
if  it has appeared the the index of current num and the index of the complement is returned
if it has been seen the first time then num and its index is stored in seen for future reference as complement

What are the time and space complexities of the above Two Sum solution, and where does the O(n) space come from?
time complexity is O(n) and space complexity is O(n) the O(n) is from the already existing numbers list and seen dict
"""
# Out:
# ' \nExplain this in plain English:\nseen = {}\nfor i, num in enumerate(numbers):\n    complement = target - num\n    if complement in seen:\n        return [seen[complement], i]\n    seen[num] = i\nDon\'t just say "it uses hashing."\nExplain what is stored, what is searched, and when the answer is returned.\n\nthe loop is run using enumerate which gives the index and num,\nthe  num is subtracted from the target to obtain a value\nthis value is checked in seen to see whether it has appeared befor in the set\nif  it has appeared the the index of current num and the index of the complement is returned\nif it has been seen the first time then num and its index is stored in seen for future reference as complement\n\nWhat are the time and space complexities of the above Two Sum solution, and where does the O(n) space come from?\ntime complexity is O(n) and space complexity is O(n) the O(n) is from the already existing numbers list and seen dict\n'

# %%
def contains_duplicate(numbers):
    seen=()
    for num in numbers:
        if num in seen:
            return True
        seen.add(num)
    return False

# %%
def first_duplicate(numbers):
    seen=()
    for num in numbers:
        if num in seen:
            return num
        seen.add(num)
    return None
