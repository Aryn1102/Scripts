# %%
"""Interview Questions

Answer these without looking back.

Q1.
What is the time complexity of traversing an array once?

Q2.
What is the time complexity of accessing numbers[i] when you already know i?

Q3.
What is linear search?

Q4.
Why can linear search take O(n) time?

Q5.
Why do we commonly return -1 when linear search doesn't find the target?

Q6.

What is an accumulator pattern?

Q7.

What is the difference between O(n) and O(n²)?

Q8.

What is the difference between time complexity and space complexity?
Time complexity describes how the number of operations grows with input size, 
while space complexity describes how the additional memory requirement grows with input size.

Q9.

What does in-place mean?
"In-place" generally means the algorithm modifies the input using O(1) or constant extra auxiliary space.

Q10. ⭐

Consider:

def find_largest(numbers):
    largest = numbers[0]

    for number in numbers:
        if number > largest:
            largest = number

    return largest

What are its:

time complexity?
space complexity?

Explain why.
"""

# %%
""" 
Write:

def linear_search(numbers, target):

Return the index of the target.

Return -1 if it isn't present."""

# %%
""" 
Write:

def count_occurrences(numbers, target):

Example:

count_occurrences([1, 2, 2, 3, 2], 2)

Expected:

3

Don't use .count().
"""

# %%
"""" 
Write:
def find_min_max(numbers):
Return:
(minimum, maximum)
Don't use min() or max().
"""

# %%
""" 
LC 1929: Concatenation of Array
LC 1480: Running Sum of 1d Array
LC 1470: Shuffle the Array
LC 283: Move Zeroes
LC 27: Remove Element
"""
