# %%
import sqlite3

# %%
conn = sqlite3.connect('academy.db')
cursor = conn.cursor()
"""
A cursor is created from a database connection.
It is used to execute SQL queries and retrieve results.
"""
# Out:
# 'We use cursor as an object of the connection.'

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS students (
    id INTEGER PRIMARY KEY,
    name TEXT,
    age INTEGER,
    cgpa REAL,
    branch TEXT
    )
    """)
conn.commit()

# %%
cursor.execute("""
INSERT INTO students (id, name, age, cgpa, branch)
VALUES (1, 'raj', 22, 6.22, 'IT'),
       (2, 'Aman', 21, 7.8, 'CSE'),
       (3, 'Priya', 23, 8.9, 'IT'),
       (4, 'Ravi', 22, 7.1, 'CSE');
""")
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 cursor.execute("""
#       2 INSERT INTO students (id, name, age, cgpa, branch)
#       3 VALUES (1, 'raj', 22, 6.22, 'IT'),
#       4        (2, 'Aman', 21, 7.8, 'CSE'),
#
# OperationalError: database is locked

# %%
cursor.execute("SELECT * FROM students")
print(cursor.fetchall())
# Out:
# [(1, 'raj', 22, 6.22, 'IT'), (2, 'Aman', 21, 7.8, 'CSE'), (3, 'Priya', 23, 8.9, 'IT'), (4, 'Ravi', 22, 7.1, 'CSE')]

# %%
cursor.execute("SELECT * FROM students")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'raj', 22, 6.22, 'IT')
# (2, 'Aman', 21, 7.8, 'CSE')
# (3, 'Priya', 23, 8.9, 'IT')
# (4, 'Ravi', 22, 7.1, 'CSE')

# %%
cursor.execute("""
SELECT name, cgpa FROM students;
""")
rows = cursor.fetchall()
for row in rows:
    print(row)

# %%
cursor.execute("""SELECT DISTINCT branch FROM students""")
print(cursor.fetchall())
# Out:
# []

# %%
cursor.execute("SELECT * FROM students")
print(cursor.fetchall())
# Out:
# []
