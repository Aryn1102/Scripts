# %%
"""
Problem
      ↓
Data Collection
      ↓
Data Understanding
      ↓
Data Cleaning
      ↓
EDA
      ↓
Feature Engineering
      ↓
Train/Test Split
      ↓
Model Selection
      ↓
Model Training
      ↓
Evaluation
      ↓
Hyperparameter Tuning
      ↓
Deployment
      ↓
Monitoring
"""

# %%
"""
What is the ML lifecycle? 
ML lifecycle is the complete flow of a machine learning from problem statement to deployment and maintainence. 

Why is data cleaning important? 
data cleaning helps remove null records or faulty or skewed records which might affect the model performance. 

Why do we split the data? 
so that one part can be used to train the data while the other unseen data can be used to test the data 

Difference between training and testing data? 
training data is the data models use to train and testing is the unseen data model uses after training to test themselves 

What is feature engineering? 
feature engineering is modify or creating new features from existing features for model training, learn patterns more effectively.

Why do we evaluate a model? 
we evaluate model to see its performance after getting trained on the data and how well is it suited for the data and to compare different
 models before deployment.

What is overfitting? 
Overfitting occurs when a model learns the training data too closely, including noise and random patterns, causing it to perform well on 
training data but poorly on unseen data.

Why do deployed models need monitoring? 
to see if the performance is the same as in building phase, keep track of any dips in performance or any ither issues faced by user 
during deployment. if we skip eda and go directly to model training the data understanding, cleaning, feature engineering, parts will 
be missed giving us untruthful result which are unefficient to its true capabilities. in clinical prediciton it could lead to successful
 trial but in real usage it fails which could even costs life of people.
"""
